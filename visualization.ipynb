# %% [markdown]
# # SSL experiments

# %% [markdown]
# ## 1. Data pre-processing

# %% [markdown]
# ### 1.1 PointCNN_S3DIS_1.5m_0.03

# %% [markdown]
# #### 1.1.1 PointCNN_S3DIS_1.5m_0.03_4096

# %%
# !python Sampling/gen_arch_h5_pointcnn_s3dis.py --folder arch3_no_others --max_point_num 4096 --outpath arch3_no_others_s3dis_1.5m_4096
# Out:
# Namespace(block_size=1.5, folder='arch3_no_others', grid_size=0.03, max_point_num=4096, outpath='arch3_no_others_s3dis_1.5m_4096')
# 2021-04-12 19:25:31.720444-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 19:27:13.294314-Computing block id of 17080817 points...
# 2021-04-12 19:27:14.218815-Collecting points belong to each block...
# 2021-04-12 19:27:30.177537-A_SMG_portico_exclude_others.txt is split into 430 blocks.
# 2021-04-12 19:27:30.180824-24 of 430 blocks are merged.
# 2021-04-12 19:27:56.909924-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_s3dis_1.5m_4096/test/A_SMG_portico_exclude_others_4096_zero_0.h5...
# ...

# %% [markdown]
# #### PointCNN_S3DIS_1.5m_0.03_2048

# %%
# !python Sampling/gen_arch_h5_pointcnn_s3dis.py --folder arch3_no_others --max_point_num 2048 --outpath arch3_no_others_s3dis_1.5m_2048
# Out:
# Namespace(block_size=1.5, folder='arch3_no_others', grid_size=0.03, max_point_num=2048, outpath='arch3_no_others_s3dis_1.5m_2048')
# 2021-04-12 19:33:54.525241-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 19:35:39.078300-Computing block id of 17080817 points...
# 2021-04-12 19:35:40.034872-Collecting points belong to each block...
# 2021-04-12 19:35:55.528964-A_SMG_portico_exclude_others.txt is split into 430 blocks.
# 2021-04-12 19:35:55.531624-20 of 430 blocks are merged.
# 2021-04-12 19:36:22.610451-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_s3dis_1.5m_2048/test/A_SMG_portico_exclude_others_2048_zero_0.h5...
# ...

# %%
# !python sampling/prepare_arch_filelist_all.py --folder ./data/arch3_no_others_s3dis_1.5m_2048
# Out:
# Namespace(folder='./data/arch3_no_others_s3dis_1.5m_2048', h5_num=4, repeat_num=2)
# 2021-05-10 15:39:17.518198-Saving ./data/arch3_no_others_s3dis_1.5m_2048/train_data_files.txt...
# 2021-05-10 15:39:17.518375-Saving ./data/arch3_no_others_s3dis_1.5m_2048/val_data_files.txt...
# 2021-05-10 15:39:17.518504-Saving ./data/arch3_no_others_s3dis_1.5m_2048/test_data_files.txt...

# %% [markdown]
# ### 1.2 PointCNN_SEMANTIC3D_2.5_0.05

# %% [markdown]
# #### PointCNN_SEMANTIC3D_2.5_0.05_4096

# %%
# !python Sampling/gen_arch_h5_pointcnn_semantic3d.py --folder arch3_no_others --max_point_num 4096 --outpath arch3_no_others_semantic3d_2.5m_4096
# Out:
# Namespace(block_size=2.5, folder='arch3_no_others', grid_size=0.05, max_point_num=4096, outpath='arch3_no_others_semantic3d_2.5m_4096')
# 2021-04-12 19:43:01.104401-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 19:44:42.288771-Computing block id of 17080817 points...
# 2021-04-12 19:44:43.331704-Collecting points belong to each block...
# 2021-04-12 19:44:58.306991-A_SMG_portico_exclude_others.txt is split into 175 blocks.
# 2021-04-12 19:44:58.309443-6 of 175 blocks are merged.
# 2021-04-12 19:45:19.824481-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_semantic3d_2.5m_4096/test/A_SMG_portico_exclude_others_4096_zero_0.h5...
# ...

# %% [markdown]
# #### PointCNN_SEMANTIC3D_2.5_0.05_2048

# %%
# !python Sampling/gen_arch_h5_pointcnn_semantic3d.py --folder arch3_no_others --max_point_num 2048 --outpath arch3_no_others_semantic3d_2.5m_2048
# Out:
# Namespace(block_size=2.5, folder='arch3_no_others', grid_size=0.05, max_point_num=2048, outpath='arch3_no_others_semantic3d_2.5m_2048')
# 2021-04-12 19:50:47.490376-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 19:52:27.143600-Computing block id of 17080817 points...
# 2021-04-12 19:52:28.193556-Collecting points belong to each block...
# 2021-04-12 19:52:43.653671-A_SMG_portico_exclude_others.txt is split into 175 blocks.
# 2021-04-12 19:52:43.656134-6 of 175 blocks are merged.
# 2021-04-12 19:53:04.123288-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_semantic3d_2.5m_2048/test/A_SMG_portico_exclude_others_2048_zero_0.h5...
# ...

# %% [markdown]
# ### 1.3 PointCNN_COMBINED_1.5_0.03

# %% [markdown]
# #### 1.3.1 PointCNN_COMBINED_1.5_0.03_4096

# %%
# !python Sampling/gen_arch_h5_pointcnn_combine.py --folder arch3_no_others --max_point_num 4096 --outpath arch3_no_others_combined_1.5m_4096
# Out:
# Namespace(block_size=1.5, folder='arch3_no_others', grid_size=0.03, max_point_num=4096, outpath='arch3_no_others_combined_1.5m_4096')
# 2021-04-12 20:02:43.375232-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 20:04:25.507780-Computing block id of 17080817 points...
# 2021-04-12 20:04:26.483856-Collecting points belong to each block...
# 2021-04-12 20:04:42.270316-A_SMG_portico_exclude_others.txt is split into 430 blocks.
# 2021-04-12 20:04:42.273587-24 of 430 blocks are merged.
# 2021-04-12 20:05:10.622833-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_1.5m_4096/test/A_SMG_portico_exclude_others_4096_zero_0.h5...
# ...

# %% [markdown]
# #### 1.3.2 PointCNN_COMBINED_1.5_0.03_2048

# %%
# !python Sampling/gen_arch_h5_pointcnn_combine.py --folder arch3_no_others --max_point_num 2048 --outpath arch3_no_others_combined_1.5m_2048
# Out:
# Namespace(block_size=1.5, folder='arch3_no_others', grid_size=0.03, max_point_num=2048, outpath='arch3_no_others_combined_1.5m_2048')
# 2021-04-12 20:11:05.650407-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 20:12:47.235016-Computing block id of 17080817 points...
# 2021-04-12 20:12:48.177632-Collecting points belong to each block...
# 2021-04-12 20:13:03.638106-A_SMG_portico_exclude_others.txt is split into 430 blocks.
# 2021-04-12 20:13:03.640763-20 of 430 blocks are merged.
# 2021-04-12 20:13:30.788632-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_1.5m_2048/test/A_SMG_portico_exclude_others_2048_zero_0.h5...
# ...

# %%
# !python sampling/prepare_arch_filelist_all.py --folder ./data/arch3_no_others_combined_1.5m_2048
# Out:
# Namespace(folder='./data/arch3_no_others_combined_1.5m_2048', h5_num=4, repeat_num=2)
# 2021-05-10 15:40:08.095198-Saving ./data/arch3_no_others_combined_1.5m_2048/train_data_files.txt...
# 2021-05-10 15:40:08.095560-Saving ./data/arch3_no_others_combined_1.5m_2048/val_data_files.txt...
# 2021-05-10 15:40:08.095776-Saving ./data/arch3_no_others_combined_1.5m_2048/test_data_files.txt...

# %% [markdown]
# ### 1.4 PointCNN_COMBINED_2.5_0.05

# %% [markdown]
# #### 1.4.1 PointCNN_COMBINED_2.5_0.05_4096

# %%
# !python Sampling/gen_arch_h5_pointcnn_combine.py --folder arch3_no_others --block_size 2.5 --grid_size 0.05 --max_point_num 4096 --outpath arch3_no_others_combined_2.5m_4096
# Out:
# Namespace(block_size=2.5, folder='arch3_no_others', grid_size=0.05, max_point_num=4096, outpath='arch3_no_others_combined_2.5m_4096')
# 2021-04-12 20:19:23.496867-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 20:21:04.274024-Computing block id of 17080817 points...
# 2021-04-12 20:21:05.196699-Collecting points belong to each block...
# 2021-04-12 20:21:20.199156-A_SMG_portico_exclude_others.txt is split into 175 blocks.
# 2021-04-12 20:21:20.201645-6 of 175 blocks are merged.
# 2021-04-12 20:21:41.449467-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_2.5m_4096/test/A_SMG_portico_exclude_others_4096_zero_0.h5...
# ...

# %%
# !python sampling/prepare_arch_filelist_all.py --folder ./data/arch3_no_others_combined_2.5m_4096
# Out:
# Namespace(folder='./data/arch3_no_others_combined_2.5m_4096', h5_num=4, repeat_num=2)
# 2021-05-12 14:04:29.308726-Saving ./data/arch3_no_others_combined_2.5m_4096/train_data_files.txt...
# 2021-05-12 14:04:29.309067-Saving ./data/arch3_no_others_combined_2.5m_4096/val_data_files.txt...
# 2021-05-12 14:04:29.309332-Saving ./data/arch3_no_others_combined_2.5m_4096/test_data_files.txt...

# %% [markdown]
# #### 1.4.2 PointCNN_COMBINED_2.5_0.05_2048

# %%
# !python Sampling/gen_arch_h5_pointcnn_combine.py --folder arch3_no_others --block_size 2.5 --grid_size 0.05 --max_point_num 2048 --outpath arch3_no_others_combined_2.5m_2048
# Out:
# Namespace(block_size=2.5, folder='arch3_no_others', grid_size=0.05, max_point_num=2048, outpath='arch3_no_others_combined_2.5m_2048')
# 2021-04-12 20:27:05.398201-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 20:28:45.996621-Computing block id of 17080817 points...
# 2021-04-12 20:28:46.928447-Collecting points belong to each block...
# 2021-04-12 20:29:02.057761-A_SMG_portico_exclude_others.txt is split into 175 blocks.
# 2021-04-12 20:29:02.060159-6 of 175 blocks are merged.
# 2021-04-12 20:29:22.522688-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_2.5m_2048/test/A_SMG_portico_exclude_others_2048_zero_0.h5...
# ...

# %% [markdown]
# ### 1.5 PointCNN_COMBINED_5_0.1

# %% [markdown]
# #### 1.5.1 PointCNN_COMBINED_5_0.1_4096

# %%
# !python Sampling/gen_arch_h5_pointcnn_combine.py --folder arch3_no_others --block_size 5 --grid_size 0.1 --max_point_num 4096 --outpath arch3_no_others_combined_5m_4096
# Out:
# Namespace(block_size=5.0, folder='arch3_no_others', grid_size=0.1, max_point_num=4096, outpath='arch3_no_others_combined_5m_4096')
# 2021-04-12 20:34:47.921842-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 20:36:27.584493-Computing block id of 17080817 points...
# 2021-04-12 20:36:28.519081-Collecting points belong to each block...
# 2021-04-12 20:36:43.634556-A_SMG_portico_exclude_others.txt is split into 56 blocks.
# 2021-04-12 20:36:43.635165-1 of 56 blocks are merged.
# 2021-04-12 20:37:02.793529-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_5m_4096/test/A_SMG_portico_exclude_others_4096_zero_0.h5...
# ...

# %%
# !python sampling/prepare_arch_filelist_all.py --folder ./data/arch3_no_others_combined_5m_4096
# Out:
# Namespace(folder='./data/arch3_no_others_combined_5m_4096', h5_num=4, repeat_num=2)
# 2021-05-12 13:55:31.445305-Saving ./data/arch3_no_others_combined_5m_4096/train_data_files.txt...
# 2021-05-12 13:55:31.445511-Saving ./data/arch3_no_others_combined_5m_4096/val_data_files.txt...
# 2021-05-12 13:55:31.445620-Saving ./data/arch3_no_others_combined_5m_4096/test_data_files.txt...

# %% [markdown]
# #### 1.5.2 PointCNN_COMBINED_5_0.1_2048

# %%
# !python Sampling/gen_arch_h5_pointcnn_combine.py --folder arch3_no_others --block_size 5 --grid_size 0.1 --max_point_num 2048 --outpath arch3_no_others_combined_5m_2048
# Out:
# Namespace(block_size=5.0, folder='arch3_no_others', grid_size=0.1, max_point_num=2048, outpath='arch3_no_others_combined_5m_2048')
# 2021-04-12 20:42:20.222266-Loading /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others/test/A_SMG_portico_exclude_others.txt...
# 2021-04-12 20:44:00.238489-Computing block id of 17080817 points...
# 2021-04-12 20:44:01.189400-Collecting points belong to each block...
# 2021-04-12 20:44:16.328513-A_SMG_portico_exclude_others.txt is split into 56 blocks.
# 2021-04-12 20:44:16.329113-1 of 56 blocks are merged.
# 2021-04-12 20:44:34.737939-Saving /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_5m_2048/test/A_SMG_portico_exclude_others_2048_zero_0.h5...
# ...

# %% [markdown]
# ## 2. test dataloader moudule

# %%
import os
import sys
sys.path.append(os.path.join('.','data_preprocessing'))
import arch_dataloader
split='train'
arch_data_dir = './data/arch3_no_others_combined_1.5m_2048'
train_filelist = os.path.join(arch_data_dir, "train_data_files.txt")
train_dataset = arch_dataloader.get_dataloader(filelist=train_filelist, num_points=2048, num_dims=3, split='train', batch_size=32, num_workers=4)
print("classifer set size: " + str(train_dataset.dataset.__len__()))

# %% [markdown]
# ## 3. Rotate pc

# %% [markdown]
# ### 3.1 Generate Rotated data

# %%
### pre-code
import os
import sys
sys.path.append(os.path.join('.','data_preprocessing'))
import arch_dataloader
import pre_rotation
import numpy as np
import h5py
import argparse
import numpy as np
from datetime import datetime

# read data
split='train'
arch_data_dir = './data/arch3_no_others_combined_1.5m_2048'
train_filelist = os.path.join(arch_data_dir, "train_data_files.txt")
train_dataset = arch_dataloader.get_dataloader(filelist=train_filelist, num_points=2048, num_dims=3, split='train', batch_size=32, num_workers=4, drop_last=True)
print("classifer set size: " + str(train_dataset.dataset.__len__()))

file_size = 2048
batch_size = 128
point_num = 2048
NUM_CLASSES = 4
batch_num = file_size / batch_size
rotated_dataset = np.zeros((file_size, point_num, 3))
rotated_labelset = np.zeros((file_size), dtype=np.int32)
idx = 0
idx_h5 = 0
sample_name = 'combined_1.5m'
# rotate data 
for iter, data in enumerate(train_dataset):
    input_points, _ = data
    rotated_data, rotated_label = pre_rotation.rotate_pc(current_data=input_points, NUM_CLASSES=4)
    start = idx*batch_size
    end = (idx+1)*batch_size
    rotated_dataset[start:end, ...] = rotated_data
    rotated_labelset[start:end, ...] = rotated_label
    idx += 1
    if (idx == batch_num):
        filename_h5 = os.path.join('./data', 'rotated_%d_angle_%s_%d' % (NUM_CLASSES, sample_name, point_num), '%d.h5' % idx_h5)
        print('{}-Saving {}...'.format(datetime.now(), filename_h5))
        file = h5py.File(filename_h5, 'w')
        file.create_dataset('data', data=rotated_dataset[0:end, ...])
        file.create_dataset('label', data=rotated_labelset[0:end, ...])
        file.close()
        idx_h5 +=1
        idx = 0

# %%
# !python data_preprocessing/pre_rotation.py --NUM_ANGLES 6 --max_point_num 4096 --outpath 'rotated_6_angle_combined_5m_4096'
# Out:
# Namespace(NUM_ANGLES=6, batch_size=32, folder=None, max_point_num=4096, outpath='rotated_6_angle_combined_5m_4096', split='train')
# Read datasets by load .h5 files, filelist: /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_5m_4096/train_data_files.txt
# Load file: ./train/7_SMV_chapel_24_exclude_others_4096_zero_0.h5
#
# Load file: ./train/8_SMV_chapel_28_4096_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_4096_zero_0.h5
#
# Load file: ./train/7_SMV_chapel_24_exclude_others_4096_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_4096_half_0.h5
#
# Load file: ./train/8_SMV_chapel_28_4096_zero_0.h5
#
# size of all point_set: [(6502, 4096, 3),(6502, 4096)]
# classifer set size: 6502
# Expanded data shape: torch.Size([192, 4096, 3])
# Expanded data shape: torch.Size([192, 4096, 3])
# Expanded data shape: torch.Size([192, 4096, 3])
# Expanded data shape: torch.Size([192, 4096, 3])
# ...

# %%
import os
import random
from datetime import datetime

arch_data_dir = './data/rotated_6_angle_combined_5m_4096'
train_h5 = []
train_h5 = os.listdir(arch_data_dir)
print(train_h5)
random.shuffle(train_h5)
train_list = os.path.join(arch_data_dir, 'train_data_files.txt')
print('{}-Saving {}...'.format(datetime.now(), train_list))
with open(train_list, 'w') as filelist:
    for filenames in train_h5:
        filelist.write(filenames+'\n')
# Out:
# ['9.h5', '15.h5', '12.h5', '13.h5', '17.h5', '3.h5', '6.h5', '1.h5', '14.h5', '5.h5', '11.h5', '7.h5', '16.h5', '8.h5', '0.h5', '2.h5', '4.h5', '10.h5']
# 2021-05-12 15:14:53.133520-Saving ./data/rotated_6_angle_combined_5m_4096/train_data_files.txt...

# %% [markdown]
# ### 3.2 Test & Visualize Rotated PC

# %%
import matplotlib.pyplot as plt
def pyplot_draw_point_cloud(points, label):
    """ points is a Nx3 numpy array """
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(points[:,0], points[:,1], points[:,2])
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    ax.set_title(label)
    fig.show()

# %% [markdown]
# #### 3.2.1 arch3_no_others_combined_1.5m_2048

# %%
import os
import sys
sys.path.append(os.path.join('.','data_preprocessing'))
import arch_dataloader
import pre_rotation
import numpy as np
import h5py
import argparse
import numpy as np
from datetime import datetime


# read data
split='train'
arch_data_dir = './data/arch3_no_others_combined_1.5m_2048'
train_filelist = os.path.join(arch_data_dir, "train_data_files.txt")
train_dataset = arch_dataloader.get_dataloader(filelist=train_filelist, num_points=2048, num_dims=3, split='train', batch_size=1, num_workers=4, drop_last=True)
print("classifer set size: " + str(train_dataset.dataset.__len__()))

# rotate data 
for iter, data in enumerate(train_dataset):
    input_points, _ = data
    rotated_data, rotated_label = pre_rotation.rotate_pc(current_data=input_points, NUM_CLASSES=6)
    print(rotated_label)
    for iter, data in enumerate(rotated_data):
        pyplot_draw_point_cloud(data, rotated_label[iter])
    break
# Out:
# Read datasets by load .h5 files, filelist: ./data/arch3_no_others_combined_1.5m_2048/train_data_files.txt
# Load file: ./train/5_SMV_chapel_1_exclude_others_2048_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_2048_zero_0.h5
#
# Load file: ./train/7_SMV_chapel_24_exclude_others_2048_zero_0.h5
#
# Load file: ./train/8_SMV_chapel_28_2048_zero_0.h5
#
# Load file: ./train/7_SMV_chapel_24_exclude_others_2048_half_0.h5
#
# Load file: ./train/8_SMV_chapel_28_2048_half_0.h5
#
# size of all point_set: [(11713, 2048, 3),(11713, 2048)]
# classifer set size: 11713
# Expanded data shape: torch.Size([6, 2048, 3])
# [0 1 2 3 4 5]
# <ipython-input-2-6f74e8695512>:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# #### 3.2.2 arch3_no_others_combined_5m_4096

# %%
import os
import sys
sys.path.append(os.path.join('.','data_preprocessing'))
import arch_dataloader
import pre_rotation
import numpy as np


# read data
split='train'
arch_data_dir = './data/arch3_no_others_combined_5m_4096'
train_filelist = os.path.join(arch_data_dir, "train_data_files.txt")
train_dataset = arch_dataloader.get_dataloader(filelist=train_filelist, num_points=4096, num_dims=3, split='train', batch_size=1, num_workers=4, drop_last=True)
print("classifer set size: " + str(train_dataset.dataset.__len__()))


# rotate data 
for iter, data in enumerate(train_dataset):
    input_points, _ = data
    rotated_data, rotated_label = pre_rotation.rotate_pc(current_data=input_points, NUM_CLASSES=6)
    print(rotated_label)
    for iter, data in enumerate(rotated_data):
        pyplot_draw_point_cloud(data, rotated_label[iter])
    break
# Out:
# Read datasets by load .h5 files, filelist: ./data/arch3_no_others_combined_5m_4096/train_data_files.txt
# Load file: ./train/7_SMV_chapel_24_exclude_others_4096_zero_0.h5
#
# Load file: ./train/8_SMV_chapel_28_4096_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_4096_zero_0.h5
#
# Load file: ./train/7_SMV_chapel_24_exclude_others_4096_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_4096_half_0.h5
#
# Load file: ./train/8_SMV_chapel_28_4096_zero_0.h5
#
# size of all point_set: [(6502, 4096, 3),(6502, 4096)]
# classifer set size: 6502
# Expanded data shape: torch.Size([6, 4096, 3])
# [0 1 2 3 4 5]
# <ipython-input-2-6f74e8695512>:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### 3.3 Load Rotated data

# %%
import os
import sys
sys.path.append(os.path.join('.','data_preprocessing'))
import arch_dataloader
split='train'
arch_data_dir = './data/rotated_6_angle_combined_5m_4096'
train_filelist = os.path.join(arch_data_dir, "train_data_files.txt")
train_dataset = arch_dataloader.get_dataloader(filelist=train_filelist, num_points=4096, num_dims=3, split='train', is_rotated=True, batch_size=32, num_workers=8)
print("classifer set size: " + str(train_dataset.dataset.__len__()))
# Out:
# Read datasets by load .h5 files, filelist: ./data/rotated_6_angle_combined_5m_4096/train_data_files.txt
# Load file: 7.h5
#
# Load file: 17.h5
#
# Load file: 10.h5
#
# Load file: 16.h5
#
# Load file: 8.h5
#
# Load file: 14.h5
#
# Load file: 13.h5
#
# Load file: 12.h5
#
# Load file: 5.h5
#
# Load file: 4.h5
#
# Load file: 3.h5
#
# Load file: 15.h5
#
# Load file: 2.h5
#
# Load file: 0.h5
#
# Load file: 1.h5
#
# Load file: 9.h5
#
# Load file: 11.h5
#
# Load file: 6.h5
#
# size of all point_set: [(38016, 4096, 3),(38016,)]
# classifer set size: 38016

# %% [markdown]
# ## 4.Pretext-task Design

# %% [markdown]
# ## 5. train reconstruction & rotation prediction

# %% [markdown]
# ### 5.1 rotated point cloud, outputed to h5 files, and train

# %%
# !python main.py --batch_size 4 --workers 4 --num_points 4096

# %% [markdown]
# ### 5.2 Training with rotating

# %%
# !python model/rotation_train.py --batch_size 4 --workers 4 --num_points 4096
# Out:
# Logging to /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/LOG/multitask_arch_rot_angles_6_sample_combined_block_size_5m_4096_point_dims_3_feat_dims_512_batch_4
# -Now loading ArCH dataset...
# Read datasets by load .h5 files, filelist: /home/marco/Documents/Experiments/code/Self-supervised-LoD3-building-segmentation/data/arch3_no_others_combined_5m_4096/train_data_files.txt
# Load file: ./train/7_SMV_chapel_24_exclude_others_4096_zero_0.h5
#
# Load file: ./train/8_SMV_chapel_28_4096_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_4096_zero_0.h5
#
# Load file: ./train/7_SMV_chapel_24_exclude_others_4096_half_0.h5
#
# Load file: ./train/5_SMV_chapel_1_exclude_others_4096_half_0.h5
#
# Load file: ./train/8_SMV_chapel_28_4096_zero_0.h5
#
# size of all point_set: [(6502, 4096, 3),(6502, 4096)]
# training set size: 6502
# training start!!!
# **** EPOCH 000 ****
# total training nuber: 6502total batch number: 1625 .
# ...
